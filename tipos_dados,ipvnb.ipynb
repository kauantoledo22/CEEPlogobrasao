# %% [markdown]
# <a href="https://colab.research.google.com/github/kauantoledo22/CEEPlogobrasao/blob/main/tipos_dados%2Cipvnb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# tipo de dados no python - revisao

#int

idade=17
print("idade:")
print(idade)
print(type(idade))

#float (ponto flutuante) valores com virgula(ponto separador de decimais)
altura=1.60

#str (string) texto
nome="maria ingrid"
print("nome:")
print(nome)
print(type(nome))

#bool - booleano: o que e um boleano galera (sim,nao,verdeade)

# (mentira,ligado,desligado) ou seja so ha uma duas opçãoes

briga = False
print("briga:")
print(briga)
print(type(briga))

#list lista (coleção ordenada)
frutas = ["blueberry", "morangi", "maça",]
print("fruta:")
print(frutas)
print(type(frutas))


#tuple - dupla, como por ecemplo, coordenadas
coordenadas = (52.640, 24.324)


#set - conjuto
numero = {1,2,2,3,3,4,5,5,5}
print("numero:")
print(numero)
print(type(numero))


#dict - dicionario
pessoas = {"nome": "nathingrid", "idade":17}

#NoneType = quando nao tem nada, mas precisa informar um valor
print("valor:")
print(valor)
print(type(valor))
valor = None
# Out:
# idade:
# 17
# <class 'int'>
# nome:
# maria ingrid
# <class 'str'>
# briga:
# False
# <class 'bool'>
# fruta:
# ['blueberry', 'morangi', 'maça']
# <class 'list'>
# numero:
# {1, 2, 3, 4, 5}
# <class 'set'>
# valor:
# None
# <class 'NoneType'>
