# %% [markdown]
# <a href="https://colab.research.google.com/github/kauantoledo22/CEEPlogobrasao/blob/main/Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%writefile programa.cs
# using System;
#
# class Program
# {
#     static void Main()
#     {
#         Console.WriteLine("Hello, World!");
#     }
# }
# !mcs programa.cs
# !mono programa.exe
# Out:
# Overwriting programa.cs
